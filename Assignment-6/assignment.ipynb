# %% [markdown]
# ## Data Cleaning and Transformation on Heart Disease Dataset
#
# In this section, we will perform data cleaning and transformation on the heart disease dataset. The steps involved are:
#
# 1. **Loading the Dataset**: Import the dataset into a pandas DataFrame.
# 2. **Handling Missing Values**: Identify and handle any missing values in the dataset.
# 3. **Data Transformation**: Apply necessary transformations to the data, such as scaling numerical features and encoding categorical variables.
# 4. **Feature Engineering**: Create new features that may be useful for the analysis or model training.
# 5. **Data Normalization**: Normalize the data to ensure that all features contribute equally to the analysis.
#
# ### Steps:
#
# 1. **Loading the Dataset**:
#     - Use `pandas` to load the dataset into a DataFrame.
#
# 2. **Handling Missing Values**:
#     - Check for missing values using `isnull()` and `sum()` methods.
#     - Decide on a strategy to handle missing values, such as imputation or removal.
#
# 3. **Data Transformation**:
#     - Use `StandardScaler` from `sklearn.preprocessing` to scale numerical features.
#     - Encode categorical variables using techniques like one-hot encoding.
#
# 4. **Feature Engineering**:
#     - Create new features based on existing ones to enhance the dataset.
#
# 5. **Data Normalization**:
#     - Normalize the dataset to ensure that all features are on a similar scale.
#
# By following these steps, we will prepare the heart disease dataset for further analysis and modeling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### Handling Missing Values
#
# Since there are no missing values in the dataset, as confirmed by the previous cell, we can proceed to the next step: data transformation.

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df_ZScaled = pd.DataFrame((df - df.mean()) / df.std())
df_ZScaled
# Out:
#            age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    -0.268306  0.661181 -0.915309 -0.377451 -0.659010 -0.418674  0.890820
# 1    -0.158080  0.661181 -0.915309  0.478874 -0.833454  2.386166 -1.003559
# 2     1.715758  0.661181 -0.915309  0.764315 -1.395551 -0.418674  0.890820
# 3     0.723726  0.661181 -0.915309  0.935580 -0.833454 -0.418674  0.890820
# 4     0.833952 -1.510969 -0.915309  0.364697  0.930368  2.386166  0.890820
# ...        ...       ...       ...       ...       ...       ...       ...
# 1020  0.503275  0.661181  0.055904  0.478874 -0.484566 -0.418674  0.890820
# 1021  0.613500  0.661181 -0.915309 -0.377451  0.232592 -0.418674 -1.003559
# 1022 -0.819434  0.661181 -0.915309 -1.233776  0.562097 -0.418674 -1.003559
# 1023 -0.488757 -1.510969 -0.915309 -1.233776  0.155061 -0.418674 -1.003559
# 1024 -0.047854  0.661181 -0.915309 -0.662893 -1.124194 -0.418674  0.890820
#
# ...

# %%
plt.plot(df_ZScaled)
plt.title('Z-Score Normalized Data')
plt.show()

# %%
plt.plot(df)
plt.title('Original Data')
plt.show()

# %% [markdown]
# ### Comparison of Original and Z-Score Normalized Data
#
# In the previous cells, we plotted two graphs to visualize the original and Z-score normalized data from the heart disease dataset. Below is an explanation of these graphs and any abnormalities observed.
#
# #### Original Data Plot
# The first plot represents the original data without any scaling or normalization. Each line in the plot corresponds to a feature in the dataset. The y-axis represents the raw values of these features.
#
# - **Observation**: The features have different ranges and scales. For example, the `age` feature ranges from around 30 to 80, while the `chol` (cholesterol) feature ranges from around 100 to 400. This discrepancy in scales can affect the performance of machine learning models, as features with larger ranges can dominate those with smaller ranges.
#
# #### Z-Score Normalized Data Plot
# The second plot represents the Z-score normalized data. Z-score normalization scales the data such that each feature has a mean of 0 and a standard deviation of 1. This is achieved by subtracting the mean and dividing by the standard deviation for each feature.
#
# - **Observation**: After normalization, all features are on a similar scale, with most values falling between -3 and 3. This makes it easier to compare the features and ensures that no single feature dominates the others in the analysis or modeling process.
#
# #### Abnormalities
# - **Original Data**: The original data plot shows significant variability in the scales of different features. This can lead to issues in machine learning models, as features with larger scales can disproportionately influence the model's performance.
# - **Z-Score Normalized Data**: The normalized data plot shows that all features are now on a similar scale, which is desirable for most machine learning algorithms. However, any outliers in the data will still be present, but their influence will be reduced due to the normalization process.
#
# By normalizing the data, we ensure that all features contribute equally to the analysis, improving the performance and reliability of machine learning models.
